# %%
import os
import numpy as np
import scipy
from collections import Counter
import sys
from IPython.display import SVG
import time
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import itertools
import matplotlib as ml

# %%
rec_rate = open("/Users/dshipilina/GitHub/scaff-1-miss0.97.rmap").read()
split_rec = rec_rate.split('\n')
rec_array=[]
print(split_red[2])
for i in split_rec:
    ii=i.split()
    rec_array+=[ii]
print(rec_array)
df = pd.DataFrame(rec_array)
df
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#               0         1                       2
# 0          3665      3701  1.1564413621526475e-08
# 1          3701      3722  1.1564413621526475e-08
# 2          3722      3799  1.1564413621526475e-08
# 3          3799      3838  1.1564413621526475e-08
# 4          3838      3842  1.1564413621526475e-08
# 5          3842      3850  1.1564413621526475e-08
# 6          3850      6419  1.1564413621526475e-08
# 7          6419      6423  1.1564413621526475e-08
# 8          6423      6426  1.1564413621526475e-08
# 9          6426      6470  1.1564413621526475e-08
# 10         6470      6523  1.1564413621526475e-08
# 11         6523      6631  1.1564413621526475e-08
# 12         6631      6647  1.1564413621526475e-08
# ...

# %%
rec_rate = open("/Users/dshipilina/GitHub/scaff-1-miss0.97.rmap").read()
split_rec = rec_rate.split('\n')
rec_array=[]
rec_array2=[]
rec_array3=[]
print(split_red[2])
for i in split_rec[:10000]:
    ii=i.split()
    #print(ii[0])
    rec_array+=[ii[0]]
    rec_array2+=[ii[1]]
    rec_array3+=[ii[2]]

a = np.array(rec_array)
start = a.astype(int)
b = np.array(rec_array2)
end = b.astype(int)
c = np.array(rec_array3)
rec = c.astype(float)
#int_array


#df = pd.DataFrame(rec_array)


#df.columns=["Start", "End","Recombination"]
#cols = ["Start", "End","Recombination"]
#df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# 3722	3800	1.5

# %%
print(start)
# Out:
# [   3665    3701    3722 ... 4563591 4563597 4565524]

# %%
df
df['Window Length'] = df["End"] - df["Start"]
df["Normalized RR"]=df['Window Length']/df['Recombination']
df
# Out:
#             Start         End  Recombination  Val_Diff  Window Length  \
# 0          3665.0      3701.0   1.156441e-08      36.0           36.0
# 1          3701.0      3722.0   1.156441e-08      21.0           21.0
# 2          3722.0      3799.0   1.156441e-08      77.0           77.0
# 3          3799.0      3838.0   1.156441e-08      39.0           39.0
# 4          3838.0      3842.0   1.156441e-08       4.0            4.0
# 5          3842.0      3850.0   1.156441e-08       8.0            8.0
# 6          3850.0      6419.0   1.156441e-08    2569.0         2569.0
# 7          6419.0      6423.0   1.156441e-08       4.0            4.0
# 8          6423.0      6426.0   1.156441e-08       3.0            3.0
# 9          6426.0      6470.0   1.156441e-08      44.0           44.0
# 10         6470.0      6523.0   1.156441e-08      53.0           53.0
# 11         6523.0      6631.0   1.156441e-08     108.0          108.0
# ...

# %%
df["End"].max()
# Out:
# 34448090.0

# %%
arr = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(arr)

# %%
df.columns=["Start", "End","Rec"]
cols = ["Start", "End","Rec"] #,"PCA4","PCA5","PCA6","PCA7","PCA8","PCA9"]
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)


windows=np.arange(1, 10000, 10)
#print(windows)
#for i in windows:
    #print(i)
    #df.loc[df['End'] >= i, 'equal_or_lower_than_4?'] = 'True' 

#df
    #if df['End']>i:
       # print("Overlap")

# %%
df["End"][4]
# Out:
# 3842.0

# %%
len(df['End'])
# Out:
# 89281

# %%
print(df['Start'][:10])
print(df['End'][:10])

#windows=np.arange(1, 10000, 10)
windows=np.arange(100000, 34000000, 100000)
#windows=[100000,200000,300000]
print("Column_N Start End Span Cut_Before Cut_After")
for i in windows:
    for j in range(89281):
        if (df['End'][j]>i) & (df['Start'][j]<i):
            #print('tyt')
            print(j,df['Start'][j],df['End'][j],df['End'][j]-df['Start'][j],i-df['Start'][j],df['End'][j]-i)
        #print(df['End'][j])
    #print((df['End']>i) & (df['Start']<i))
    #df.loc[df['End'] >= i, 'equal_or_lower_than_4?'] = 'True'
#(df['Set'] == 'Z') & (df['Type'] == 'A')
#df

#df['End'][i]
# Out:
# 0    3665.0
# 1    3701.0
# 2    3722.0
# 3    3799.0
# 4    3838.0
# 5    3842.0
# 6    3850.0
# 7    6419.0
# 8    6423.0
# 9    6426.0
# Name: Start, dtype: float64
# 0    3701.0
# 1    3722.0
# 2    3799.0
# 3    3838.0
# 4    3842.0
# 5    3850.0
# 6    6419.0
# 7    6423.0
# 8    6426.0
# 9    6470.0
# Name: End, dtype: float64
# Column_N Start End Span Cut_Before Cut_After
# 215 95204.0 100163.0 4959.0 4796.0 163.0
# 395 199250.0 201464.0 2214.0 750.0 1464.0
# 643 294562.0 303660.0 9098.0 5438.0 3660.0
# 797 399969.0 400746.0 777.0 31.0 746.0
# 1086 499765.0 500555.0 790.0 235.0 555.0
# 1336 599891.0 602635.0 2744.0 109.0 2635.0
# 1491 679218.0 717116.0 37898.0 20782.0 17116.0
# 1605 794039.0 830820.0 36781.0 5961.0 30820.0
# 1815 898423.0 901539.0 3116.0 1577.0 1539.0
# 1998 999992.0 1000100.0 108.0 8.0 100.0
# 2119 1097468.0 1101350.0 3882.0 2532.0 1350.0
# 2265 1197865.0 1200247.0 2382.0 2135.0 247.0
# ...

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-222-9ae93f22b889> in <module>()
# ----> 1 df[0]
#
# ...

# %%
windows=np.arange(1, 10000, 10)
#print(windows)
for i in windows:
    #print(i)
    #df2.loc[df2['End'] >= i, 'equal_or_lower_than_4?'] = 'True' 
    #break

#df
    
    
    if df['End']>i:
        print("Overlap")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'End'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df
# Out:
#             0        1                       2
# 0        3665     3701  1.1564413621526475e-08
# 1        3701     3722  1.1564413621526475e-08
# 2        3722     3799  1.1564413621526475e-08
# 3        3799     3838  1.1564413621526475e-08
# 4        3838     3842  1.1564413621526475e-08
# 5        3842     3850  1.1564413621526475e-08
# 6        3850     6419  1.1564413621526475e-08
# 7        6419     6423  1.1564413621526475e-08
# 8        6423     6426  1.1564413621526475e-08
# 9        6426     6470  1.1564413621526475e-08
# 10       6470     6523  1.1564413621526475e-08
# 11       6523     6631  1.1564413621526475e-08
# 12       6631     6647  1.1564413621526475e-08
# 13       6647     6668  1.1564413621526475e-08
# 14       6668     6687  1.1564413621526475e-08
# 15       6687     6688  1.1564413621526475e-08
# 16       6688     6992  1.1564413621526475e-08
# 17       6992     7556  1.1564413621526475e-08
# 18       7556    22752  1.1564413621526475e-08
# ...

# %%
df.loc[df['End'] >= i, 'equal_or_lower_than_4?'] = 'True'

# %%
df['End']>i
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 89251     True
# 89252     True
# 89253     True
# 89254     True
# 89255     True
# 89256     True
# 89257     True
# 89258     True
# 89259     True
# 89260     True
# 89261     True
# 89262     True
# 89263     True
# 89264     True
# 89265     True
# 89266     True
# 89267     True
# 89268     True
# 89269     True
# 89270     True
# 89271     True
# 89272     True
# 89273     True
# 89274     True
# 89275     True
# 89276     True
# 89277     True
# ...

# %%
end
# Out:
# array([   3701,    3722,    3799, ..., 4563597, 4565524, 4565747])

# %%
end[:100]
# Out:
# array([ 3701,  3722,  3799,  3838,  3842,  3850,  6419,  6423,  6426,
#         6470,  6523,  6631,  6647,  6668,  6687,  6688,  6992,  7556,
#        22752, 22759, 22763, 22765, 22767, 22779, 22781, 22792, 22800,
#        22801, 22813, 22822, 22828, 22831, 22836, 22841, 22843, 22848,
#        22852, 22853, 22894, 22899, 22900, 22914, 23011, 23015, 23016,
#        23017, 23020, 23047, 23052, 23056, 23062, 23065, 23067, 23068,
#        23076, 23086, 23089, 23100, 23101, 23109, 23119, 25137, 25458,
#        25600, 25645, 25684, 27089, 28532, 30759, 30767, 30901, 32836,
#        32849, 33059, 33857, 33878, 33880, 33933, 33937, 34045, 34048,
#        34061, 34068, 34070, 34121, 34123, 34126, 34130, 34134, 35009,
#        35010, 35012, 36166, 36247, 36333, 36430, 36521, 38155, 38223,
#        38379])

# %%
windows=np.arange(3700, 10000, 1000)
print(windows)
print(start[:10])
print(end[:10])

for i in windows:
    print("window border",i)
    for j in start[:10]:
        print("start position",j)
        for k in end[:10]:
            print(k)
            print("end position",k)
            k+=10
            print(k)
            break
        break
            #k+=1
            #if k > i:
                #print('r')
            #print(k,i,j)
            #if j > i:
                #print("in the win")
            #else:
                #print(j,"wow")

        #break
    #break
#break
    
    
#a = np.array(rec_array)
#start = a.astype(int)
# Out:
# [3700 4700 5700 6700 7700 8700 9700]
# [3665 3701 3722 3799 3838 3842 3850 6419 6423 6426]
# [3701 3722 3799 3838 3842 3850 6419 6423 6426 6470]
# window border 3700
# start position 3665
# 3701
# end position 3701
# 3711
# window border 4700
# start position 3665
# 3701
# end position 3701
# 3711
# window border 5700
# start position 3665
# 3701
# end position 3701
# 3711
# window border 6700
# start position 3665
# 3701
# end position 3701
# 3711
# window border 7700
# start position 3665
# 3701
# end position 3701
# 3711
# window border 8700
# start position 3665
# 3701
# end position 3701
# 3711
# window border 9700
# start position 3665
# 3701
# end position 3701
# 3711

# %%
def maxSum(arr, n, k):
 
    # Initialize result
    max_sum = INT_MIN
 
    # Consider all blocks
    # starting with i.
    for i in range(n - k + 1):
        current_sum = 0
        for j in range(k):
            current_sum = current_sum + arr[i + j]
 
        # Update result if required.
        max_sum = max(current_sum, max_sum)
 
    return max_sum
 
 
# Driver code
#arr = [1, 4, 2, 10, 2,
       3, 1, 0, 20]
#k = 4
#n = len(arr)
#print(maxSum(arr, n, k))
 
# This code is contributed by mits

# %%
arr = [1, 4, 2, 10, 2, 3, 1, 0, 20]
k = 4
n = len(arr)

# %%
for i in range(n - k + 1):
        current_sum = 0
        for j in range(k):
            print(arr[i + j])
            current_sum = current_sum + arr[i + j]
            #print(current_sum)
# Out:
# 1
# 4
# 2
# 10
# 4
# 2
# 10
# 2
# 2
# 10
# 2
# 3
# 10
# 2
# 3
# 1
# 2
# 3
# 1
# 0
# 3
# 1
# 0
# 20

# %%
def maxSum(arr, n, k):
 
    # Initialize result
    max_sum = INT_MIN
 
    # Consider all blocks
    # starting with i.
    for i in range(n - k + 1):
        current_sum = 0
        for j in range(k):
            current_sum = current_sum + arr[i + j]
 
        # Update result if required.
        max_sum = max(current_sum, max_sum)
 
    return max_sum

# %%
for i in range(n - k + 1):
        current_sum = 0

# %%
range(n - k + 1)
# Out:
# range(0, 6)

# %%
n -k +1
# Out:
# 6

# %%
def maxSum(arr, n, k):
 
    # Initialize result
    max_sum = INT_MIN
 
    # Consider all blocks
    # starting with i.
    for i in range(n - k + 1):
        current_sum = 0
        for j in range(k):
            current_sum = current_sum + arr[i + j]
 
        # Update result if required.
        max_sum = max(current_sum, max_sum)
 
    return max_sum

# %%
c=np.concatenate((start, end), axis=0)
c[3]
# Out:
# 3799

# %%
start
# Out:
# array([   3665,    3701,    3722, ..., 4563591, 4563597, 4565524])

# %%
end
# Out:
# array([   3701,    3722,    3799, ..., 4563597, 4565524, 4565747])

# %%
rec_array[:,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-f92f1b18e429> in <module>()
# ----> 1 rec_array[:,0]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
rec_array[1]
# Out:
# ['3701', '3722', '1.1564413621526475e-08']

# %%
df["End"]<1000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 89251    False
# 89252    False
# 89253    False
# 89254    False
# 89255    False
# 89256    False
# 89257    False
# 89258    False
# 89259    False
# 89260    False
# 89261    False
# 89262    False
# 89263    False
# 89264    False
# 89265    False
# 89266    False
# 89267    False
# 89268    False
# 89269    False
# 89270    False
# 89271    False
# 89272    False
# 89273    False
# 89274    False
# 89275    False
# 89276    False
# 89277    False
# ...

# %%
df2=df["Normalized RR"].rolling(window=10).mean()
df2
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9        2.425545e+10
# 10       2.440245e+10
# 11       2.515476e+10
# 12       2.462728e+10
# 13       2.447163e+10
# 14       2.460133e+10
# 15       2.454080e+10
# 16       4.954856e+09
# 17       9.797297e+09
# 18       1.411745e+11
# 19       1.408358e+11
# 20       1.403967e+11
# 21       1.394725e+11
# 22       1.393437e+11
# 23       1.391835e+11
# 24       1.390228e+11
# 25       1.390337e+11
# 26       1.364192e+11
# 27       1.315440e+11
# 28       1.622516e+08
# 29       1.364949e+08
#              ...
# 89251    1.036425e+10
# 89252    1.084057e+10
# 89253    1.011462e+10
# 89254    1.001518e+10
# 89255    5.153964e+09
# 89256    5.121282e+09
# 89257    5.119892e+09
# 89258    3.781335e+09
# 89259    3.748654e+09
# 89260    1.132036e+09
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-1c398d74db25> in <module>()
# ----> 1 df[2].rolling(window=10).sum()
#
# ...

# %%
for window in df.rolling(window=3):
    print(window)
# Out:
# Rolling [window=3,center=False,axis=0]
# Rolling [window=3,center=False,axis=0]
# Rolling [window=3,center=False,axis=0]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-032e9cccb9ed> in <module>()
# ----> 1 for window in df.rolling(window=3):
#       2     print(window)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     347         elif not getattr(self, 'as_index', False):
#     348             if key not in self.obj.columns:
# --> 349                 raise KeyError("Column not found: %s" % key)
#     350             return self._gotitem(key, ndim=2)
#     351
#
# KeyError: 'Column not found: 3'

# %%
int(rec_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-73ed95e7b062> in <module>()
# ----> 1 int(rec_array)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
df['Val10-Val1'] = df.apply(lambda x: x['Val10'] - x['Val1'], axis=1)
print df

# %%
df['Val_Diff'] = df[2] - df[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
# ...
