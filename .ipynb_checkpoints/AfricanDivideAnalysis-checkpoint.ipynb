# %%
import os
import numpy as np
import scipy
from collections import Counter
import sys
from IPython.display import SVG
import time
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import itertools
import matplotlib as ml
# %matplotlib inline
font = {'family' : 'Sans', 'weight' : 'normal','size': 16}
ml.rc('font', **font)
ml.rcParams['figure.figsize'] = (5.0, 5.0)
ml.rcParams['text.usetex'] =False
ml.rc('font', family='serif',size=12)

# %% [markdown]
# # PCA analysis
# ### Constructing main table for PCA
# #### Initialize eigenvector table

# %%
eigvec = open("/Users/dshipilina/GitHub/AfricanDivide/vanessa.eigenvec").read()
split_eig = eigvec.split('\n')
eigvec_array=[]
#print(split_file2[2])
for i in split_eig:
    ii=i.split()
    eigvec_array+=[ii]
    
print(eigvec_array[2])
    
popid = open("/Users/dshipilina/GitHub/AfricanDivide/popmap1.txt").read()
split_popid = popid.split('\n')
#print(txt2)
popID_array=[]
#print(split_file2[2])
for i in split_popid:
    ii=i.split()
    popID_array+=[ii]

df = pd.DataFrame(eigvec_array)#, columns = ["ScaffoldID", "N_BUSCOs","BUSCOs_coverage", ])
df
del df[1]
df

'''
#remove extra column
del df[1]
#remove empty row
df = df.drop(labels=[347], axis=0)
#split name
#df[[0],'allele'] = df[0].str.split('_',expand=True)
#df = pd.DataFrame(df[0].str.split('_',expand=True), columns = ["loc", "N"])
df2=df[0].str.split('_',expand=True)
#print(df2)
df2.columns=["loc", "N"]

#df2.rename({df2[1]: 'X', df2[1]: 'Y'}, axis=1, inplace=True)
#df2

#combine two
df = pd.concat([df2,df],axis=1)
#df = pd.DataFrame(df, columns = ["loc", "N","fullN"])
#df
#df.merge(df2, left_on=df[0], right_on=df2[0])

txt2 = open("/Users/dshipilina/GitHub/AfricanDivide/popmap1.txt").read()
split_file2 = txt2.split('\n')
#print(txt2)
panda=[]
#print(split_file2[2])
for i in split_file2:
    ii=i.split()
    panda+=[ii]
    
dff = pd.DataFrame(panda)
dff.columns=["pop","popID"]

df = pd.concat([dff,df],axis=1)
df

del df[2]
df

df

'''
# Out:
# ['Ethiopia_14L847', 'Ethiopia_14L847', '0.00509649', '0.0067101', '0.00327291', '-0.00874097', '0.00421669', '0.00452511', '-0.00251806', '0.00661413', '0.00536969', '0.000113937', '-0.0135118', '0.000857868', '0.0152943', '0.00294916', '-0.00314494', '0.00179594', '0.0156133', '-0.00438863', '-0.0084537', '0.0124926']
# '\n#remove extra column\ndel df[1]\n#remove empty row\ndf = df.drop(labels=[347], axis=0)\n#split name\n#df[[0],\'allele\'] = df[0].str.split(\'_\',expand=True)\n#df = pd.DataFrame(df[0].str.split(\'_\',expand=True), columns = ["loc", "N"])\ndf2=df[0].str.split(\'_\',expand=True)\n#print(df2)\ndf2.columns=["loc", "N"]\n\n#df2.rename({df2[1]: \'X\', df2[1]: \'Y\'}, axis=1, inplace=True)\n#df2\n\n#combine two\ndf = pd.concat([df2,df],axis=1)\n#df = pd.DataFrame(df, columns = ["loc", "N","fullN"])\n#df\n#df.merge(df2, left_on=df[0], right_on=df2[0])\n\ntxt2 = open("/Users/dshipilina/GitHub/AfricanDivide/popmap1.txt").read()\nsplit_file2 = txt2.split(\'\n\')\n#print(txt2)\npanda=[]\n#print(split_file2[2])\nfor i in split_file2:\n    ii=i.split()\n    panda+=[ii]\n    \ndff = pd.DataFrame(panda)\ndff.columns=["pop","popID"]\n\ndf = pd.concat([dff,df],axis=1)\ndf\n\ndel df[2]\ndf\n\ndf\n\n'

# %% [markdown]
# #### Initialize population ID table

# %%
txt2 = open("/Users/dshipilina/GitHub/AfricanDivide/popmap1.txt").read()
split_file2 = txt2.split('\n')
#print(txt2)
panda=[]
#print(split_file2[2])
for i in split_file2:
    ii=i.split()
    panda+=[ii]
    
dff = pd.DataFrame(panda)
dff.columns=["pop","popID"]

df = pd.concat([dff,df],axis=1)
df

del df[2]
df
# Out:
#                     pop popID                 pop popID                 pop  \
# 0       Ethiopia_14L679  SHEA     Ethiopia_14L679  SHEA     Ethiopia_14L679
# 1       Ethiopia_14L834  SHEA     Ethiopia_14L834  SHEA     Ethiopia_14L834
# 2       Ethiopia_14L847  SHEA     Ethiopia_14L847  SHEA     Ethiopia_14L847
# 3       Ethiopia_14L879  SHEA     Ethiopia_14L879  SHEA     Ethiopia_14L879
# 4       Ethiopia_14L880  SHEA     Ethiopia_14L880  SHEA     Ethiopia_14L880
# 5       Ethiopia_14L881  SHEA     Ethiopia_14L881  SHEA     Ethiopia_14L881
# 6       Ethiopia_14L882  SHEA     Ethiopia_14L882  SHEA     Ethiopia_14L882
# 7       Ethiopia_14L883  SHEA     Ethiopia_14L883  SHEA     Ethiopia_14L883
# 8       Ethiopia_14L884  SHEA     Ethiopia_14L884  SHEA     Ethiopia_14L884
# 9       Ethiopia_14L885  SHEA     Ethiopia_14L885  SHEA     Ethiopia_14L885
# 10      Ethiopia_14L886  SHEA     Ethiopia_14L886  SHEA     Ethiopia_14L886
# 11      Ethiopia_14L887  SHEA     Ethiopia_14L887  SHEA     Ethiopia_14L887
# 12      Ethiopia_14L888  SHEA     Ethiopia_14L888  SHEA     Ethiopia_14L888
# 13      Ethiopia_14L889  SHEA     Ethiopia_14L889  SHEA     Ethiopia_14L889
# 14      Ethiopia_14L890  SHEA     Ethiopia_14L890  SHEA     Ethiopia_14L890
# 15      Ethiopia_14L891  SHEA     Ethiopia_14L891  SHEA     Ethiopia_14L891
# 16      Ethiopia_14L892  SHEA     Ethiopia_14L892  SHEA     Ethiopia_14L892
# 17      Ethiopia_14L894  SHEA     Ethiopia_14L894  SHEA     Ethiopia_14L894
# 18      Ethiopia_14L895  SHEA     Ethiopia_14L895  SHEA     Ethiopia_14L895
# 19         Kenya_16E222  SHEA        Kenya_16E222  SHEA        Kenya_16E222
# 20         Kenya_16E223  SHEA        Kenya_16E223  SHEA        Kenya_16E223
# 21         Kenya_16E224  SHEA        Kenya_16E224  SHEA        Kenya_16E224
# 22         Kenya_16E225  SHEA        Kenya_16E225  SHEA        Kenya_16E225
# 23         Kenya_16E251  SHEA        Kenya_16E251  SHEA        Kenya_16E251
# 24      Kenya_DJM07A185  SHEA     Kenya_DJM07A185  SHEA     Kenya_DJM07A185
# 25      Kenya_DJM07A191  SHEA     Kenya_DJM07A191  SHEA     Kenya_DJM07A191
# 26      Tanzania_14K873  SHEA     Tanzania_14K873  SHEA     Tanzania_14K873
# 27      Tanzania_14K880  SHEA     Tanzania_14K880  SHEA     Tanzania_14K880
# 28      Tanzania_14K887  SHEA     Tanzania_14K887  SHEA     Tanzania_14K887
# 29      Tanzania_14K907  SHEA     Tanzania_14K907  SHEA     Tanzania_14K907
# ..                  ...   ...                 ...   ...                 ...
# 326        Spain_13S390   NHE        Spain_13S390   NHE        Spain_13S390
# 327        Spain_14K196   NHE        Spain_14K196   NHE        Spain_14K196
# 328        Spain_15D678   NHE        Spain_15D678   NHE        Spain_15D678
# 329        Spain_15D930   NHE        Spain_15D930   NHE        Spain_15D930
# 330        Spain_16D104   NHE        Spain_16D104   NHE        Spain_16D104
# 331        Spain_16D185   NHE        Spain_16D185   NHE        Spain_16D185
# 332       Sweden_12Q564   NHE       Sweden_12Q564   NHE       Sweden_12Q564
# 333       Sweden_14C065   NHE       Sweden_14C065   NHE       Sweden_14C065
# 334       Sweden_16E210   NHE       Sweden_16E210   NHE       Sweden_16E210
# 335       Sweden_16E211   NHE       Sweden_16E211   NHE       Sweden_16E211
# 336       Sweden_16H700   NHE       Sweden_16H700   NHE       Sweden_16H700
# 337  Switzerland_15H949   NHE  Switzerland_15H949   NHE  Switzerland_15H949
# 338  Switzerland_16E549   NHE  Switzerland_16E549   NHE  Switzerland_16E549
# 339  Switzerland_16E550   NHE  Switzerland_16E550   NHE  Switzerland_16E550
# 340  Switzerland_16E551   NHE  Switzerland_16E551   NHE  Switzerland_16E551
# 341  Switzerland_16E623   NHE  Switzerland_16E623   NHE  Switzerland_16E623
# 342     Tenerife_16A390   NHE     Tenerife_16A390   NHE     Tenerife_16A390
# 343      Tunisia_12N265   NHE      Tunisia_12N265   NHE      Tunisia_12N265
# 344      Tunisia_12N266   NHE      Tunisia_12N266   NHE      Tunisia_12N266
# 345      Tunisia_12N495   NHE      Tunisia_12N495   NHE      Tunisia_12N495
# 346      Tunisia_12N504   NHE      Tunisia_12N504   NHE      Tunisia_12N504
# 347      Tunisia_13S961   NHE      Tunisia_13S961   NHE      Tunisia_13S961
# 348       Turkey_07C199   NHE       Turkey_07C199   NHE       Turkey_07C199
# 349       Turkey_07C218   NHE       Turkey_07C218   NHE       Turkey_07C218
# 350       Turkey_07C220   NHE       Turkey_07C220   NHE       Turkey_07C220
# 351       Turkey_07C268   NHE       Turkey_07C268   NHE       Turkey_07C268
# 352       Turkey_07F223   NHE       Turkey_07F223   NHE       Turkey_07F223
# 353       Turkey_07F276   NHE       Turkey_07F276   NHE       Turkey_07F276
# 354      Ukraine_14B610   NHE      Ukraine_14B610   NHE      Ukraine_14B610
# 355                None  None                None  None                None
#
#     popID                 pop popID                 pop popID      ...       \
# 0    SHEA     Ethiopia_14L679  SHEA     Ethiopia_14L679  SHEA      ...
# 1    SHEA     Ethiopia_14L834  SHEA     Ethiopia_14L834  SHEA      ...
# 2    SHEA     Ethiopia_14L847  SHEA     Ethiopia_14L847  SHEA      ...
# 3    SHEA     Ethiopia_14L879  SHEA     Ethiopia_14L879  SHEA      ...
# 4    SHEA     Ethiopia_14L880  SHEA     Ethiopia_14L880  SHEA      ...
# 5    SHEA     Ethiopia_14L881  SHEA     Ethiopia_14L881  SHEA      ...
# 6    SHEA     Ethiopia_14L882  SHEA     Ethiopia_14L882  SHEA      ...
# 7    SHEA     Ethiopia_14L883  SHEA     Ethiopia_14L883  SHEA      ...
# 8    SHEA     Ethiopia_14L884  SHEA     Ethiopia_14L884  SHEA      ...
# 9    SHEA     Ethiopia_14L885  SHEA     Ethiopia_14L885  SHEA      ...
# 10   SHEA     Ethiopia_14L886  SHEA     Ethiopia_14L886  SHEA      ...
# 11   SHEA     Ethiopia_14L887  SHEA     Ethiopia_14L887  SHEA      ...
# 12   SHEA     Ethiopia_14L888  SHEA     Ethiopia_14L888  SHEA      ...
# 13   SHEA     Ethiopia_14L889  SHEA     Ethiopia_14L889  SHEA      ...
# 14   SHEA     Ethiopia_14L890  SHEA     Ethiopia_14L890  SHEA      ...
# 15   SHEA     Ethiopia_14L891  SHEA     Ethiopia_14L891  SHEA      ...
# 16   SHEA     Ethiopia_14L892  SHEA     Ethiopia_14L892  SHEA      ...
# 17   SHEA     Ethiopia_14L894  SHEA     Ethiopia_14L894  SHEA      ...
# 18   SHEA     Ethiopia_14L895  SHEA     Ethiopia_14L895  SHEA      ...
# 19   SHEA        Kenya_16E222  SHEA        Kenya_16E222  SHEA      ...
# 20   SHEA        Kenya_16E223  SHEA        Kenya_16E223  SHEA      ...
# 21   SHEA        Kenya_16E224  SHEA        Kenya_16E224  SHEA      ...
# 22   SHEA        Kenya_16E225  SHEA        Kenya_16E225  SHEA      ...
# 23   SHEA        Kenya_16E251  SHEA        Kenya_16E251  SHEA      ...
# 24   SHEA     Kenya_DJM07A185  SHEA     Kenya_DJM07A185  SHEA      ...
# 25   SHEA     Kenya_DJM07A191  SHEA     Kenya_DJM07A191  SHEA      ...
# 26   SHEA     Tanzania_14K873  SHEA     Tanzania_14K873  SHEA      ...
# 27   SHEA     Tanzania_14K880  SHEA     Tanzania_14K880  SHEA      ...
# 28   SHEA     Tanzania_14K887  SHEA     Tanzania_14K887  SHEA      ...
# 29   SHEA     Tanzania_14K907  SHEA     Tanzania_14K907  SHEA      ...
# ..    ...                 ...   ...                 ...   ...      ...
# 326   NHE        Spain_13S390   NHE        Spain_13S390   NHE      ...
# 327   NHE        Spain_14K196   NHE        Spain_14K196   NHE      ...
# 328   NHE        Spain_15D678   NHE        Spain_15D678   NHE      ...
# 329   NHE        Spain_15D930   NHE        Spain_15D930   NHE      ...
# 330   NHE        Spain_16D104   NHE        Spain_16D104   NHE      ...
# 331   NHE        Spain_16D185   NHE        Spain_16D185   NHE      ...
# 332   NHE       Sweden_12Q564   NHE       Sweden_12Q564   NHE      ...
# 333   NHE       Sweden_14C065   NHE       Sweden_14C065   NHE      ...
# 334   NHE       Sweden_16E210   NHE       Sweden_16E210   NHE      ...
# 335   NHE       Sweden_16E211   NHE       Sweden_16E211   NHE      ...
# 336   NHE       Sweden_16H700   NHE       Sweden_16H700   NHE      ...
# 337   NHE  Switzerland_15H949   NHE  Switzerland_15H949   NHE      ...
# 338   NHE  Switzerland_16E549   NHE  Switzerland_16E549   NHE      ...
# 339   NHE  Switzerland_16E550   NHE  Switzerland_16E550   NHE      ...
# 340   NHE  Switzerland_16E551   NHE  Switzerland_16E551   NHE      ...
# 341   NHE  Switzerland_16E623   NHE  Switzerland_16E623   NHE      ...
# 342   NHE     Tenerife_16A390   NHE     Tenerife_16A390   NHE      ...
# 343   NHE      Tunisia_12N265   NHE      Tunisia_12N265   NHE      ...
# 344   NHE      Tunisia_12N266   NHE      Tunisia_12N266   NHE      ...
# 345   NHE      Tunisia_12N495   NHE      Tunisia_12N495   NHE      ...
# 346   NHE      Tunisia_12N504   NHE      Tunisia_12N504   NHE      ...
# 347   NHE      Tunisia_13S961   NHE      Tunisia_13S961   NHE      ...
# 348   NHE       Turkey_07C199   NHE       Turkey_07C199   NHE      ...
# 349   NHE       Turkey_07C218   NHE       Turkey_07C218   NHE      ...
# 350   NHE       Turkey_07C220   NHE       Turkey_07C220   NHE      ...
# 351   NHE       Turkey_07C268   NHE       Turkey_07C268   NHE      ...
# 352   NHE       Turkey_07F223   NHE       Turkey_07F223   NHE      ...
# 353   NHE       Turkey_07F276   NHE       Turkey_07F276   NHE      ...
# 354   NHE      Ukraine_14B610   NHE      Ukraine_14B610   NHE      ...
# 355  None                None  None                None  None      ...
#
#                12            13            14            15            16  \
# 0     -0.00796403   -0.00542999     0.0130618   -0.00407043     -0.013985
# 1      0.00941516    0.00900516     0.0115592  -0.000407395     0.0298766
# 2      -0.0135118   0.000857868     0.0152943    0.00294916   -0.00314494
# 3      0.00869839    0.00683017     0.0102995   -0.00188781    -0.0056058
# 4     -0.00136622    0.00332958  -0.000658744     0.0071255   0.000937175
# 5      -0.0295068   -0.00246775     0.0222788   0.000536213    -0.0120052
# 6     -0.00026059     0.0116436   -0.00212361    0.00334936    0.00130555
# 7      -0.0217837   -0.00840871    -0.0236335     0.0494586   -0.00678474
# 8       0.0569799    0.00981485     0.0793193   -0.00269079     0.0926291
# 9      6.4094e-05    0.00757264     0.0102772    0.00787501    -0.0014812
# 10     0.00864323    0.00343454   0.000773586   -0.00416542   -0.00143775
# 11    -0.00263624   -0.00150058    -0.0137412    -0.0183635     0.0223634
# 12    -0.00217627    0.00293411    0.00406168    0.00956439   -0.00504153
# 13     0.00215165     0.0188088     -0.022378    0.00592578   -0.00989769
# 14    -0.00482444    0.00801773      0.016318   -0.00590344   -0.00596537
# 15    -0.00183065    0.00418391    0.00584369  -0.000981183   -0.00990404
# 16    -0.00367452   -0.00209756     0.0186558    -0.0107135     0.0234284
# 17    -0.00350634     0.0010319   -0.00657093     0.0050718   -0.00646104
# 18     0.00728398    0.00408967   0.000723854    0.00163506    0.00524465
# 19    -0.00843933     0.0117373    -0.0112031    -0.0188726   -0.00865569
# 20   -0.000284459   0.000658587    0.00657451    0.00153007    0.00085629
# 21    -0.00347533    0.00760357    -0.0132777   -0.00766166     0.0045439
# 22      0.0195912     0.0158661    -0.0242294    -0.0151416   -0.00658434
# 23       0.334921      0.017808      0.014284      0.104244     -0.159105
# 24     -0.0003559  -0.000705708    0.00480679   0.000211798  -0.000210237
# 25    0.000698205   -0.00162792    0.00323024      0.011195    0.00399981
# 26     -0.0082194   -0.00467231    -0.0252855    -0.0195466     0.0219304
# 27     0.00466097   -0.00483763   -0.00299425   -0.00282133   0.000663291
# 28     -0.0394559     -0.052161     0.0299364     0.0561129     -0.105811
# 29     -0.0130868    0.00185918    -0.0103247     0.0240994     0.0210339
# ..            ...           ...           ...           ...           ...
# 326    0.00926411    0.00784007     0.0249522   -0.00769775     0.0217475
# 327     0.0073615    0.00783766     0.0237558   -0.00940004     0.0111035
# 328    -0.0342038     -0.020624     -0.013741     0.0439645     -0.021459
# 329    0.00466339     0.0029705     -0.003412    0.00454989   0.000671298
# 330     0.0148313     0.0204386   -0.00331588     0.0102768    0.00321411
# 331    -0.0037093    0.00286605     0.0116971   -0.00365282    -0.0014706
# 332   0.000309916     0.0117366    0.00954954    0.00268978    0.00396319
# 333   -0.00692076    0.00607728    0.00914206    0.00717745   -0.00705002
# 334     0.0261303      0.363735     -0.473679     0.0535136     -0.174889
# 335   -0.00345474    -0.0135705   -0.00183858    -0.0123265     0.0166152
# 336    0.00586162    0.00870845   -0.00717464  -0.000772489   0.000638349
# 337    0.00339351     -0.005998    0.00326049   -0.00879287     0.0172302
# 338   -0.00088911    0.00263542    0.00247831     0.0018802  -3.14503e-05
# 339    -0.0097534    0.00219111    0.00557344    0.00399372   0.000464724
# 340   0.000481573   -0.00105614    0.00606176    0.00349862   0.000281963
# 341    0.00493715    0.00739429    0.00819876   -0.00172588   -0.00302328
# 342   -0.00267835    0.00631659   -0.00121711    0.00770106     0.0032386
# 343     0.0107175    -0.0042541   8.84675e-05    0.00315581   -0.00311901
# 344   -0.00902304  -0.000184315    0.00252771     0.0127427    0.00289599
# 345   -0.00710641   0.000542778    -0.0075588     0.0145198    0.00253244
# 346    -0.0062539   -0.00132968  -0.000416833    -0.0237678    0.00522433
# 347           NaN           NaN           NaN           NaN           NaN
# 348           NaN           NaN           NaN           NaN           NaN
# 349           NaN           NaN           NaN           NaN           NaN
# 350           NaN           NaN           NaN           NaN           NaN
# 351           NaN           NaN           NaN           NaN           NaN
# 352           NaN           NaN           NaN           NaN           NaN
# 353           NaN           NaN           NaN           NaN           NaN
# 354           NaN           NaN           NaN           NaN           NaN
# 355           NaN           NaN           NaN           NaN           NaN
#
#                17            18            19           20            21
# 0     0.000742671    4.3853e-05     0.0281243   -0.0111482     0.0066373
# 1      0.00334394    0.00276224   -0.00995356   0.00838329    0.00783897
# 2      0.00179594     0.0156133   -0.00438863   -0.0084537     0.0124926
# 3      0.00458867    0.00547103     -0.011965    0.0189529    0.00942332
# 4     -0.00055555    0.00932841    0.00480762   -0.0120903    0.00780011
# 5       0.0137365   -0.00150935     0.0154588    0.0157681    -0.0195958
# 6      0.00516381   -0.00629589   -0.00432384  -0.00603755    -0.0210165
# 7     0.000152194   -0.00353108   0.000454224   0.00489513    -0.0113229
# 8      -0.0242721      0.016817     -0.050835     0.133631    0.00386561
# 9      0.00894296   -0.00861412    -0.0120581   -0.0153355    0.00603343
# 10    5.31306e-05   -0.00647226    -0.0093415    0.0106594  -2.78687e-05
# 11   -3.68285e-05    0.00659756  -0.000538736  -0.00620233    0.00759664
# 12     -0.0036939     0.0143567    -0.0068287  -0.00806679     0.0171754
# 13    -0.00599119    -0.0138244    0.00584991    0.0019583    0.00178945
# 14      0.0190942    0.00482397     0.0142516    0.0110228    -0.0058123
# 15    -0.00548386    -0.0185252     -0.015617  -0.00400072   -0.00137713
# 16      -0.041209   6.20648e-05     0.0270535   -0.0225122     -0.011606
# 17     0.00193429    -0.0148058      0.013677  -0.00839686       0.02033
# 18     0.00515755    0.00824042    0.00311134   -0.0263054    0.00750733
# 19     0.00103586     0.0198012     0.0114915    0.0216254    -0.0109446
# 20    -0.00991605   -0.00831759   -0.00256155   -0.0211825     0.0242727
# 21    -0.00289039   -0.00743426   -0.00399072   0.00192073     0.0081965
# 22    -0.00955209     0.0314219     0.0116072   0.00907022    -0.0119398
# 23     -0.0317375     -0.342535     -0.122886   -0.0150139    -0.0846484
# 24    -0.00158767    0.00152499    0.00209475  -0.00751688    0.00533538
# 25    -0.00997279    0.00185291   0.000584104   -0.0142077   0.000987073
# 26     0.00457034    0.00372733     0.0123196   -0.0112447     0.0108647
# 27     0.00232151     0.0146571    -0.0124481  -0.00490525   -0.00803798
# 28      -0.089214     0.0730981     -0.138382    -0.141751      0.395025
# 29    0.000155115    -0.0126626     0.0307917   0.00190649   0.000202905
# ..            ...           ...           ...          ...           ...
# 326   -0.00993176    0.00985714     0.0117259    0.0293058    -0.0176156
# 327    0.00370837    0.00355862    -0.0107594   -0.0401364     0.0235984
# 328    0.00728082     0.0211404      0.027825   -0.0169967    -0.0382628
# 329   -0.00265728   0.000791851  -0.000717484    -0.014157    0.00352134
# 330   -0.00044336     -0.018463     0.0190184  0.000591951    0.00828049
# 331    0.00373038    0.00196345  -0.000570347  -0.00328715  -0.000235389
# 332     0.0178846    0.00330327    0.00342179   0.00175771   -0.00597436
# 333    0.00413788      0.018267      0.017401   -0.0127357     0.0133261
# 334    -0.0967697      -0.52297      0.158678     0.183278      0.104763
# 335    0.00428752    0.00126851    -0.0017786   0.00554344    0.00315851
# 336   -0.00233505    0.00668164   -0.00377655   -0.0113854    0.00239844
# 337      0.020294   -0.00441966   -0.00518898  0.000170935    0.00407604
# 338  -0.000556778     0.0127011   -0.00746048  -0.00402006     0.0104069
# 339   -0.00649111  -0.000242527   -0.00311925  -0.00918106    0.00601671
# 340     0.0039326   0.000357407   -0.00572054   -0.0027859     -0.002558
# 341     0.0108638     0.0254176     0.0030269    -0.015567    0.00238285
# 342   -0.00153067    0.00722085     0.0069229    0.0016489     0.0112369
# 343   -0.00172791   -0.00490947   0.000228253  -0.00426362    0.00875099
# 344    0.00492432    0.00454664     0.0012269  -0.00418959    -0.0102833
# 345    0.00215825   -0.00727049    0.00428559  -0.00209849    0.00852546
# 346   -0.00241743    0.00278704    -0.0110392   -0.0112824    0.00353342
# 347           NaN           NaN           NaN          NaN           NaN
# 348           NaN           NaN           NaN          NaN           NaN
# 349           NaN           NaN           NaN          NaN           NaN
# 350           NaN           NaN           NaN          NaN           NaN
# 351           NaN           NaN           NaN          NaN           NaN
# 352           NaN           NaN           NaN          NaN           NaN
# 353           NaN           NaN           NaN          NaN           NaN
# 354           NaN           NaN           NaN          NaN           NaN
# 355           NaN           NaN           NaN          NaN           NaN
#
# [356 rows x 31 columns]

# %% [markdown]
# #### Plotting

# %%
#print(df['loc'])
sns.scatterplot(x=df[3], y=df[4], hue=df['loc'],palette="YlOrBr_r")
#sns.barplot(x=chroname, y=repcov) #, palette="deep") #, ax=ax3)
plt.ylabel("PCA 2")
plt.xlabel("PCA 1")
plt.xticks(rotation=90)
#plt.axis('off')
plt.xticks([0,100,200,300],[])
plt.yticks([0,100,200,300],[])
ml.rcParams['figure.figsize'] = (7.0, 7.0)
#plt.legend([])
#plt.legend('',frameon=False)
plt.savefig("/Users/dshipilina/Documents/GitHub/AfricanDivide/PCA1_2_locs.png")
#plt.show()

#print(df['loc'])
sns.scatterplot(x=df[4], y=df[5], hue=df['loc'],palette="YlOrBr_r")
#sns.barplot(x=chroname, y=repcov) #, palette="deep") #, ax=ax3)
plt.ylabel("PCA 3")
plt.xlabel("PCA 2")
plt.xticks(rotation=90)
#plt.axis('off')
plt.xticks([0,100,200,300],[])
plt.yticks([0,100,200,300],[])
ml.rcParams['figure.figsize'] = (7.0, 7.0)
#plt.legend([])
plt.legend(frameon=False)
plt.savefig("/Users/dshipilina/Documents/GitHub/AfricanDivide/PCA2_3_locs.png")
#plt.show()

# %%
txt2 = open("pacbio.hic.scaflen.merge.txt").read()
split_file2 = txt2.split('\n')
fram=[]
for i in split_file2:
    ii=i.replace('>', '')
    iii=''.join(ii)
    j=iii.split()
    fram+=[j]

#print(fram)   
#df3 = pd.DataFrame(fram)
#df3

txt = open("busco_scaffold.txt").read()
split_file = txt.split('\n')
#print(txt2)
fram2=[]
for i in split_file:
    ii=i.replace('>', '')
    iii=''.join(ii)
    j=iii.split()
    fram2+=[j]
    
#print(fram2)

#comb_data=pd.DataFrame(data)
#data = {"ScaffoldID": fram, "Scaffold_Length","N_BUSCOs","BUSCOs_coverage"   'Name':['Tom', 'nick', 'krish', 'jack'], 
     #   'Age':[20, 21, 19, 18]} 
#comb_data=pd.DataFrame(data)

df3 = pd.DataFrame(fram2, columns = ["ScaffoldID", "N_BUSCOs","BUSCOs_coverage"])
df3["N_BUSCOs"]=pd.to_numeric(df3["N_BUSCOs"])
df3["BUSCOs_coverage"]=pd.to_numeric(df3["BUSCOs_coverage"])

df4=pd.DataFrame(fram, columns = ["ID", "Scaffold_Length"])
df4["Scaffold_Length"]=pd.to_numeric(df4["Scaffold_Length"])

df4

dat2 = df3
dat1 = df4
comb_data=dat1.join(dat2)
comb_data
comb_data = comb_data.sort_values("Scaffold_Length", ascending=False)
